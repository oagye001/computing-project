# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_excel('EDGARv5.0_FT2019_fossil_CO2_booklet2020.xls',sheet_name='fossil_CO2_totals_by_country')
dataset.head()
# Out:
#   country_name       1970       1971       1972       1973       1974  \
# 0  Afghanistan   1.477495   1.475813   1.529543   1.486272   1.913149
# 1      Albania   4.715734   4.716046   5.370307   4.794843   5.161438
# 2      Algeria  18.925177  22.310183  34.368864  46.468952  39.294911
# 3       Angola   8.952568   8.538305  10.388559  11.371997  11.832577
# 4     Anguilla   0.002168   0.002168   0.002264   0.002109   0.002350
#
#         1975       1976       1977       1978  ...        2010        2011  \
# 0   1.713586   1.630803   1.894227   1.639085  ...    5.641922    6.923214
# 1   5.235304   5.597622   5.988796   6.818050  ...    4.599695    4.995170
# 2  35.704259  46.316589  51.284903  56.554711  ...  116.437387  122.790563
# 3  10.929284   7.316239  12.056612  14.238036  ...   23.810684   24.774455
# 4   0.002584   0.002434   0.002537   0.002902  ...    0.024005    0.026008
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
dataset[1970].values
# Out:
# array([1.47749548e+00, 4.71573375e+00, 1.89251766e+01, 8.95256826e+00,
#        2.16828960e-03, 1.20809974e-01, 8.87599264e+01, 1.09160123e+01,
#        2.12925798e-02, 1.60991384e+02, 5.39810676e+01, 3.22768216e+01,
#        1.61712464e+00, 2.96194179e+00, 3.34764004e+00, 2.93622941e-01,
#        6.41768879e+01, 1.40358452e+02, 6.15329610e-02, 3.20453848e-01,
#        1.61207397e-01, 3.78294602e-02, 3.07282065e+00, 1.57384964e+01,
#        2.86478326e-01, 1.09516493e+02, 6.62132694e-03, 2.04205961e+00,
#        7.05756618e+01, 2.45775354e-01, 4.83083566e-02, 1.83580044e-01,
#        2.23704164e-01, 9.00120137e-01, 3.59783946e+02, 2.00919649e-02,
#        8.26287544e-02, 1.63389057e-01, 2.78725997e+01, 9.06561968e+02,
#        3.16752731e+01, 2.31146405e-02, 1.80609882e+00, 1.97338240e-02,
#        1.44622467e+00, 2.63896748e+00, 2.19976485e+01, 2.17410164e+01,
#        4.72536497e+00, 2.17170897e+00, 1.90078178e+02, 2.33687999e+00,
# ...

# %%
uk = dataset.loc[dataset.country_name == 'United Kingdom'].values.flatten()
uk.tolist()
print(uk)
# Out:
# ['United Kingdom' 684.526221477 676.1256179341 654.8621930109
#  687.0354466162 643.8883909689 623.363458318101 628.971240635001
#  639.301745146299 639.0564744158 674.665083861 613.8797474004
#  594.0672778044 580.1979127021 571.6721735329 554.9803476444
#  581.2139583364 594.2352011662 600.1293650702 601.02168028969
#  586.6354545381 588.0675169287 596.118741450799 582.5675124718
#  567.046385323 562.1909505205 554.1289937964 571.9800025947 548.6762174108
#  550.5262150216 546.2265351828 552.979212714699 566.1338927901
#  550.3173391302 563.5681196866 563.4974557544 561.557714702 562.0224525894
#  551.6648993445 536.636904919 485.7523052085 502.3858528449 462.7668666318
#  486.975454306 471.61769437126 432.63779070639 415.62622622498
#  392.20932544954 380.10981177711 373.469062224457 364.906494709852]

# %%
europedf = pd.DataFrame.melt(dataset, var_name='Year', value_name = 'Emission total', id_vars = ['country_name'])
europedf.head()
# Out:
#   country_name  Year  Emission total
# 0  Afghanistan  1970        1.477495
# 1      Albania  1970        4.715734
# 2      Algeria  1970       18.925177
# 3       Angola  1970        8.952568
# 4     Anguilla  1970        0.002168

# %%
europe = ['Albania','Armenia','Austria','Azerbaijan','Belarus','Belgium','Bosnia and Herzegovina','Bulgaria','Croatia','Cyprus','Czechia','Denmark','Estonia','Finland','France','Georgia','Germany','Greece','HUngary','Iceland','Ireland','Italy','Kazakhstan','Latvia','Lithuania','Luxembourg','Malta','Moldova', 'Netherlands', 'North Macedonia','Norway','Poland','Portugal','Romania','Russia','Serbia','Slovakia','Slovenia','Spain','Sweden','Switzerland','Turkey','Ukraine','United Kingdom']
europedf['country_name'] = europedf['country_name'].astype(pd.CategoricalDtype(categories = europe,ordered = True))
europedf['country_name'].dtype
# Out:
# CategoricalDtype(categories=['Albania', 'Armenia', 'Austria', 'Azerbaijan', 'Belarus',
#                   'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia',
#                   'Cyprus', 'Czechia', 'Denmark', 'Estonia', 'Finland',
#                   'France', 'Georgia', 'Germany', 'Greece', 'HUngary',
#                   'Iceland', 'Ireland', 'Italy', 'Kazakhstan', 'Latvia',
#                   'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Netherlands',
#                   'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania',
#                   'Russia', 'Serbia', 'Slovakia', 'Slovenia', 'Spain',
#                   'Sweden', 'Switzerland', 'Turkey', 'Ukraine',
#                   'United Kingdom'],
#                  ordered=True)

# %%
europedf.dropna(inplace = True)
europedf.head(20)
# Out:
#               country_name  Year  Emission total
# 1                  Albania  1970        4.715734
# 7                  Armenia  1970       10.916012
# 10                 Austria  1970       53.981068
# 11              Azerbaijan  1970       32.276822
# 16                 Belarus  1970       64.176888
# 17                 Belgium  1970      140.358452
# 23  Bosnia and Herzegovina  1970       15.738496
# 28                Bulgaria  1970       70.575662
# 46                 Croatia  1970       21.997649
# 49                  Cyprus  1970        2.171709
# 50                 Czechia  1970      190.078178
# 52                 Denmark  1970       62.386342
# 61                 Estonia  1970       14.444402
# 67                 Finland  1970       43.747471
# 72                 Georgia  1970       25.891990
# 73                 Germany  1970     1082.060101
# 76                  Greece  1970       30.094726
# 88                 Iceland  1970        1.934906
# ...

# %%
#filterdf = europedf.loc[]
#filterlist = filterdf['Emission total']
#print(filterlist)

# %%
templist = []
user_country = input("Enter the country that you want to see emissions totals for: ")
templist.append(user_country)
# Out:
# Enter the country that you want to see emissions totals for: Germany

# %%
searchdf = pd.DataFrame.melt(dataset, var_name='Year', value_name = 'Emission total', id_vars = ['country_name'])
searchdf['country_name'] = searchdf['country_name'].astype(pd.CategoricalDtype(categories = templist,ordered = True))
searchdf['country_name'].dtype
# Out:
# CategoricalDtype(categories=['Germany'], ordered=True)

# %%
searchdf.dropna(inplace = True)
searchdf.head(20)
# Out:
#      country_name  Year  Emission total
# 73        Germany  1970     1082.060101
# 286       Germany  1971     1076.528453
# 499       Germany  1972     1103.053862
# 712       Germany  1973     1152.573475
# 925       Germany  1974     1122.372697
# 1138      Germany  1975     1062.510811
# 1351      Germany  1976     1123.098286
# 1564      Germany  1977     1103.363819
# 1777      Germany  1978     1141.319066
# 1990      Germany  1979     1191.263633
# 2203      Germany  1980     1138.269585
# 2416      Germany  1981     1102.721408
# 2629      Germany  1982     1056.182764
# 2842      Germany  1983     1071.762199
# 3055      Germany  1984     1087.745343
# 3268      Germany  1985     1090.351609
# 3481      Germany  1986     1083.824676
# 3694      Germany  1987     1074.868701
# 3907      Germany  1988     1068.511715
# 4120      Germany  1989     1054.590106

# %%
plt.bar(searchdf['Year'], searchdf['Emission total'])
plt.show()

# %%
plt.plot(searchdf['Year'], searchdf['Emission total'])
plt.show()

# %%
#user_year = int(input("Enter the year that you want to see emissions totals for Europe: "))

#plt.bar(x_pos, )
#plt.show()
